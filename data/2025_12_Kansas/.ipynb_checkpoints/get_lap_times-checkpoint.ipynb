# %%
import json
import pandas as pd
import numpy as np

# %%
driver_id = 0

# %%
# Get data into dataframe
with open('lap-times.json', 'r') as f:
    data = json.load(f)


df = pd.DataFrame(data['laps'][driver_id]['Laps'])

print(df)
# Out:
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           1
# 1      1   32.328  167.038           1
# 2      2   30.288  178.288           1
# 3      3   30.600  176.471           1
# 4      4   30.678  176.022           1
# ..   ...      ...      ...         ...
# 263  263   32.973  163.770           1
# 264  264   33.257  162.372           1
# 265  265   33.456  161.406           1
# 266  266   33.522  161.088           1
# 267  267   33.922  159.189           1
#
# [268 rows x 4 columns]

# %%
# get driver name
driver_name = pd.DataFrame(data['laps'][driver_id])
driver_name = driver_name['FullName'][driver_id]

driver_name = driver_name.lstrip('* ').rstrip(' #')

print(driver_name)
# Out:
# Kyle Larson

# %%
# save as csv
driver_name = driver_name + '.csv'

print(driver_name)
df.to_csv(driver_name)
# Out:
# Kyle Larson.csv

# %%
print(len(df['Lap']))
# Out:
# 268

# %%
for x in np.arange(43):

    driver_id = x
    
    # Get data into dataframe
    with open('lap-times.json', 'r') as f:
        data = json.load(f)
    
    
    df = pd.DataFrame(data['laps'][driver_id]['Laps'])
    
    print(df)
    
    # get driver name
    driver_name = pd.DataFrame(data['laps'][driver_id])
    driver_name = driver_name['FullName'][driver_id]
    driver_name = driver_name.lstrip('* ').rstrip(' #').rstrip('(i)')
    
    print(driver_name)
    
    
    # save as csv
    driver_name = driver_name + '.csv'
    
    print(driver_name)
    df.to_csv(driver_name)
# Out:
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           1
# 1      1   32.328  167.038           1
# 2      2   30.288  178.288           1
# 3      3   30.600  176.471           1
# 4      4   30.678  176.022           1
# ..   ...      ...      ...         ...
# 263  263   32.973  163.770           1
# 264  264   33.257  162.372           1
# 265  265   33.456  161.406           1
# 266  266   33.522  161.088           1
# 267  267   33.922  159.189           1
#
# [268 rows x 4 columns]
# Kyle Larson
# Kyle Larson.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           3
# 1      1   32.568  165.807           3
# 2      2   30.360  177.866           2
# 3      3   30.759  175.558           2
# 4      4   30.786  175.404           2
# ..   ...      ...      ...         ...
# 263  263   33.118  163.053           2
# 264  264   33.364  161.851           2
# 265  265   33.102  163.132           2
# 266  266   33.322  162.055           2
# 267  267   33.270  162.308           2
#
# [268 rows x 4 columns]
# Christopher Bell
# Christopher Bell.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          10
# 1      1   33.068  163.300           9
# 2      2   30.838  175.109           7
# 3      3   31.213  173.005           8
# 4      4   30.977  174.323           7
# ..   ...      ...      ...         ...
# 263  263   32.656  165.360           3
# 264  264   33.075  163.265           3
# 265  265   32.687  165.203           3
# 266  266   32.727  165.001           3
# 267  267   32.782  164.725           3
#
# [268 rows x 4 columns]
# Ryan Blaney
# Ryan Blaney.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          19
# 1      1   32.987  163.701          31
# 2      2   32.291  167.229          32
# 3      3   32.235  167.520          35
# 4      4   31.941  169.062          35
# ..   ...      ...      ...         ...
# 263  263   33.270  162.308           4
# 264  264   33.768  159.915           4
# 265  265   33.439  161.488           4
# 266  266   33.582  160.800           4
# 267  267   33.702  160.228           4
#
# [268 rows x 4 columns]
# Chase Briscoe
# Chase Briscoe.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          21
# 1      1   32.930  163.984          16
# 2      2   31.188  173.144          14
# 3      3   30.744  175.644          11
# 4      4   31.004  174.171          10
# ..   ...      ...      ...         ...
# 263  263   33.548  160.963           5
# 264  264   33.626  160.590           5
# 265  265   33.671  160.375           5
# 266  266   33.699  160.242           5
# 267  267   33.857  159.494           5
#
# [268 rows x 4 columns]
# Alex Bowman
# Alex Bowman.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          38
# 1      1   33.060  163.339          37
# 2      2   31.933  169.104          36
# 3      3   31.700  170.347          33
# 4      4   32.087  168.292          33
# ..   ...      ...      ...         ...
# 263  263   32.532  165.990           6
# 264  264   32.465  166.333           6
# 265  265   32.612  165.583           6
# 266  266   32.482  166.246           6
# 267  267   32.449  166.415           6
#
# [268 rows x 4 columns]
# Josh Berry
# Josh Berry.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          30
# 1      1   33.337  161.982          26
# 2      2   32.020  168.645          26
# 3      3   31.522  171.309          25
# 4      4   31.525  171.293          24
# ..   ...      ...      ...         ...
# 263  263   33.356  161.890           7
# 264  264   33.302  162.152           7
# 265  265   33.252  162.396           7
# 266  266   33.432  161.522           7
# 267  267   33.550  160.954           7
#
# [268 rows x 4 columns]
# Ryan Preece
# Ryan Preece.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           2
# 1      1   32.577  165.761           2
# 2      2   30.483  177.148           3
# 3      3   30.968  174.374           3
# 4      4   30.733  175.707           3
# ..   ...      ...      ...         ...
# 263  263   33.239  162.460           8
# 264  264   33.174  162.778           8
# 265  265   33.209  162.607           8
# 266  266   33.285  162.235           8
# 267  267   33.365  161.846           8
#
# [268 rows x 4 columns]
# Chris Buescher
# Chris Buescher.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           5
# 1      1   32.773  164.770           4
# 2      2   30.698  175.907           4
# 3      3   31.124  173.500           5
# 4      4   31.244  172.833           5
# ..   ...      ...      ...         ...
# 263  263   32.956  163.855           9
# 264  264   33.049  163.394           9
# 265  265   33.185  162.724           9
# 266  266   33.065  163.315           9
# 267  267   33.209  162.607           9
#
# [268 rows x 4 columns]
# Joey Logano
# Joey Logano.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          17
# 1      1   33.230  162.504          19
# 2      2   31.434  171.789          18
# 3      3   31.734  170.164          18
# 4      4   31.828  169.662          19
# ..   ...      ...      ...         ...
# 263  263   32.894  164.164          10
# 264  264   32.942  163.924          10
# 265  265   33.010  163.587          10
# 266  266   33.200  162.651          10
# 267  267   33.132  162.984          10
#
# [268 rows x 4 columns]
# John Hunter Nemechek
# John Hunter Nemechek.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          13
# 1      1   33.227  162.518          15
# 2      2   31.653  170.600          17
# 3      3   31.389  172.035          16
# 4      4   31.420  171.865          16
# ..   ...      ...      ...         ...
# 263  263   32.745  164.911          11
# 264  264   32.699  165.143          11
# 265  265   33.086  163.211          11
# 266  266   33.240  162.455          11
# 267  267   33.095  163.167          11
#
# [268 rows x 4 columns]
# Austin Cindric
# Austin Cindric.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          23
# 1      1   33.499  161.199          25
# 2      2   31.853  169.529          25
# 3      3   31.392  172.018          23
# 4      4   31.715  170.266          23
# ..   ...      ...      ...         ...
# 263  263   32.727  165.001          13
# 264  264   32.751  164.880          13
# 265  265   32.884  164.214          12
# 266  266   32.937  163.949          12
# 267  267   32.965  163.810          12
#
# [268 rows x 4 columns]
# Todd Gilliland
# Todd Gilliland.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          28
# 1      1   33.373  161.807          23
# 2      2   32.408  166.626          30
# 3      3   32.102  168.214          32
# 4      4   31.862  169.481          32
# ..   ...      ...      ...         ...
# 263  263   33.099  163.147          14
# 264  264   33.007  163.602          14
# 265  265   32.837  164.449          14
# 266  266   33.165  162.822          13
# 267  267   33.233  162.489          13
#
# [268 rows x 4 columns]
# Corey Heim
# Corey Heim.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          24
# 1      1   33.392  161.715          22
# 2      2   31.555  171.130          21
# 3      3   31.531  171.260          21
# 4      4   32.100  168.224          22
# ..   ...      ...      ...         ...
# 263  263   32.752  164.875          15
# 264  264   32.982  163.726          15
# 265  265   32.925  164.009          15
# 266  266   33.064  163.320          14
# 267  267   33.258  162.367          14
#
# [268 rows x 4 columns]
# Noah Gragson
# Noah Gragson.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           9
# 1      1   32.871  164.279           8
# 2      2   31.140  173.410           9
# 3      3   31.144  173.388           9
# 4      4   31.240  172.855           9
# ..   ...      ...      ...         ...
# 263  263   33.691  160.280          12
# 264  264   33.625  160.595          12
# 265  265   33.616  160.638          13
# 266  266   33.839  159.579          15
# 267  267   34.423  156.872          15
#
# [268 rows x 4 columns]
# Chase Elliott
# Chase Elliott.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          18
# 1      1   33.170  162.798          30
# 2      2   32.011  168.692          28
# 3      3   32.087  168.292          31
# 4      4   31.804  169.790          31
# ..   ...      ...      ...         ...
# 263  263   33.297  162.177          16
# 264  264   33.313  162.099          16
# 265  265   33.413  161.614          16
# 266  266   33.477  161.305          16
# 267  267   33.502  161.184          16
#
# [268 rows x 4 columns]
# Zane Smith
# Zane Smith.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           4
# 1      1   32.966  163.805           6
# 2      2   31.098  173.645           6
# 3      3   31.094  173.667           6
# 4      4   30.979  174.312           6
# ..   ...      ...      ...         ...
# 263  263   33.734  160.076          17
# 264  264   33.842  159.565          17
# 265  265   34.318  157.352          17
# 266  266   34.526  156.404          17
# 267  267   34.597  156.083          17
#
# [268 rows x 4 columns]
# Tyler Reddick
# Tyler Reddick.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          26
# 1      1   32.932  163.974          18
# 2      2   31.499  171.434          19
# 3      3   31.717  170.256          19
# 4      4   31.732  170.175          18
# ..   ...      ...      ...         ...
# 263  263   33.583  160.796          18
# 264  264   33.460  161.387          18
# 265  265   33.441  161.478          18
# 266  266   33.443  161.469          19
# 267  267   33.398  161.686          18
#
# [268 rows x 4 columns]
# Ross Chastain
# Ross Chastain.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          27
# 1      1   33.254  162.386          24
# 2      2   31.574  171.027          23
# 3      3   31.865  169.465          24
# 4      4   31.895  169.306          25
# ..   ...      ...      ...         ...
# 263  263   33.551  160.949          19
# 264  264   33.616  160.638          19
# 265  265   33.179  162.754          19
# 266  266   33.178  162.758          18
# 267  267   33.653  160.461          19
#
# [268 rows x 4 columns]
# Ricky Stenhouse Jr.
# Ricky Stenhouse Jr..csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          34
# 1      1   33.270  162.308          35
# 2      2   32.308  167.141          37
# 3      3   32.361  166.868          37
# 4      4   31.907  169.242          37
# ..   ...      ...      ...         ...
# 263  263   33.454  161.416          20
# 264  264   33.777  159.872          20
# 265  265   33.727  160.109          20
# 266  266   33.687  160.299          20
# 267  267   33.898  159.301          20
#
# [268 rows x 4 columns]
# Shane Van Gisbergen
# Shane Van Gisbergen.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          35
# 1      1   33.375  161.798          33
# 2      2   32.188  167.764          33
# 3      3   32.127  168.083          34
# 4      4   31.976  168.877          34
# ..   ...      ...      ...         ...
# 262  262   32.882  164.224          23
# 263  263   32.811  164.579          22
# 264  264   32.872  164.274          21
# 265  265   33.042  163.428          21
# 266  266   33.062  163.330          21
#
# [267 rows x 4 columns]
# Kyle Busch
# Kyle Busch.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          20
# 1      1   33.568  160.867          20
# 2      2   31.552  171.146          20
# 3      3   31.551  171.151          20
# 4      4   31.761  170.020          20
# ..   ...      ...      ...         ...
# 262  262   33.702  160.228          22
# 263  263   33.819  159.674          21
# 264  264   34.120  158.265          22
# 265  265   33.701  160.233          22
# 266  266   34.179  157.992          22
#
# [267 rows x 4 columns]
# Austin Dillon
# Austin Dillon.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          11
# 1      1   33.161  162.842          11
# 2      2   31.512  171.363          13
# 3      3   31.282  172.623          14
# 4      4   31.734  170.164          15
# ..   ...      ...      ...         ...
# 262  262   33.668  160.390          24
# 263  263   33.683  160.318          23
# 264  264   33.417  161.594          23
# 265  265   33.746  160.019          23
# 266  266   33.517  161.112          23
#
# [267 rows x 4 columns]
# Michael McDowell
# Michael McDowell.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           7
# 1      1   32.746  164.906           5
# 2      2   30.688  175.965           5
# 3      3   30.896  174.780           4
# 4      4   31.026  174.048           4
# ..   ...      ...      ...         ...
# 262  262   33.968  158.973          25
# 263  263   34.072  158.488          24
# 264  264   33.752  159.991          24
# 265  265   33.718  160.152          24
# 266  266   33.798  159.773          24
#
# [267 rows x 4 columns]
# William Byron
# William Byron.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          31
# 1      1   33.345  161.943          29
# 2      2   31.619  170.783          24
# 3      3   31.873  169.422          26
# 4      4   31.904  169.258          27
# ..   ...      ...      ...         ...
# 261  261   33.326  162.036          26
# 262  262   33.859  159.485          26
# 263  263   33.727  160.109          25
# 264  264   33.984  158.898          25
# 265  265   34.494  156.549          25
#
# [266 rows x 4 columns]
# Cole Custer
# Cole Custer.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          22
# 1      1   33.099  163.147          17
# 2      2   31.343  172.287          16
# 3      3   31.102  173.622          15
# 4      4   31.586  170.962          14
# ..   ...      ...      ...         ...
# 261  261   35.576  151.788          18
# 262  262   38.844  139.018          21
# 263  263   70.383   76.723          26
# 264  264   47.263  114.254          26
# 265  265   33.391  161.720          26
#
# [266 rows x 4 columns]
# Carson Hocevar
# Carson Hocevar.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          25
# 1      1   33.111  163.088          21
# 2      2   31.827  169.667          22
# 3      3   31.507  171.390          22
# 4      4   31.540  171.211          21
# ..   ...      ...      ...         ...
# 261  261   33.352  161.909          27
# 262  262   33.751  159.995          27
# 263  263   33.691  160.280          27
# 264  264   33.891  159.334          27
# 265  265   34.263  157.604          27
#
# [266 rows x 4 columns]
# Riley Herbst
# Riley Herbst.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           6
# 1      1   33.268  162.318          28
# 2      2   32.191  167.749          31
# 3      3   31.836  169.619          29
# 4      4   31.780  169.918          30
# ..   ...      ...      ...         ...
# 260  260   33.465  161.363          28
# 261  261   33.752  159.991          28
# 262  262   34.039  158.642          28
# 263  263   33.694  160.266          28
# 264  264   34.491  156.563          28
#
# [265 rows x 4 columns]
# Ty Gibbs
# Ty Gibbs.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          32
# 1      1   33.340  161.968          27
# 2      2   31.957  168.977          27
# 3      3   31.686  170.422          27
# 4      4   31.593  170.924          26
# ..   ...      ...      ...         ...
# 260  260   33.516  161.117          29
# 261  261   33.945  159.081          29
# 262  262   33.381  161.769          29
# 263  263   33.549  160.959          29
# 264  264   33.488  161.252          29
#
# [265 rows x 4 columns]
# Jesse Love
# Jesse Love.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          37
# 1      1   33.771  159.901          38
# 2      2   32.101  168.219          38
# 3      3   32.404  166.646          38
# 4      4   32.203  167.686          38
# ..   ...      ...      ...         ...
# 257  257   33.889  159.344          30
# 258  258   34.298  157.444          30
# 259  259   35.114  153.785          30
# 260  260   35.572  151.805          30
# 261  261   35.912  150.368          30
#
# [262 rows x 4 columns]
# Cody Ware
# Cody Ware.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          12
# 1      1   33.242  162.445          12
# 2      2   31.267  172.706          12
# 3      3   31.405  171.947          13
# 4      4   31.457  171.663          12
# ..   ...      ...      ...         ...
# 251  251   34.251  157.660          31
# 252  252   34.147  158.140          31
# 253  253   34.130  158.219          31
# 254  254   34.359  157.164          31
# 255  255   34.272  157.563          31
#
# [256 rows x 4 columns]
# Justin Haley
# Justin Haley.csv
#      Lap   LapTime LapSpeed  RunningPos
# 0      0       NaN     None          16
# 1      1    33.217  162.567          14
# 2      2    31.482  171.527          15
# 3      3    31.805  169.785          17
# 4      4    31.599  170.891          17
# ..   ...       ...      ...         ...
# 214  214  1343.783    4.019          32
# 215  215    35.236  153.252          32
# 216  216    35.642  151.507          32
# 217  217    35.254  153.174          32
# 218  218    35.400  152.542          32
#
# [219 rows x 4 columns]
# Erik Jones
# Erik Jones.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          15
# 1      1   32.958  163.845          13
# 2      2   30.893  174.797          10
# 3      3   31.247  172.817          10
# 4      4   31.444  171.734          11
# ..   ...      ...      ...         ...
# 208  208   95.421   56.591          23
# 209  209   99.688   54.169          22
# 210  210   99.479   54.283          23
# 211  211  112.888   47.835          23
# 212  212   79.054   68.308          23
#
# [213 rows x 4 columns]
# Bubba Wallace
# Bubba Wallace.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           8
# 1      1   33.006  163.607           7
# 2      2   31.098  173.645           8
# 3      3   31.145  173.383           7
# 4      4   31.363  172.177           8
# ..   ...      ...      ...         ...
# 197  197  102.040   52.920          19
# 198  198   65.340   82.645          19
# 199  199   59.284   91.087          19
# 200  200   79.731   67.728          19
# 201  201   57.085   94.596          24
#
# [202 rows x 4 columns]
# Daniel Suarez
# Daniel Suarez.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          29
# 1      1   33.175  162.773          36
# 2      2   32.000  168.750          35
# 3      3   32.480  166.256          36
# 4      4   31.693  170.385          36
# ..   ...      ...      ...         ...
# 193  193  108.277   49.872          36
# 194  194  101.766   53.063          36
# 195  195   66.226   81.539          35
# 196  196   57.628   93.704          35
# 197  197   81.492   66.264          34
#
# [198 rows x 4 columns]
# Ty Dillon
# Ty Dillon.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          14
# 1      1   32.884  164.214          10
# 2      2   31.421  171.860          11
# 3      3   31.156  173.321          12
# 4      4   31.817  169.721          13
# ..   ...      ...      ...         ...
# 192  192   31.380  172.084           4
# 193  193   31.301  172.518           4
# 194  194   31.360  172.194           4
# 195  195   37.714  143.183           3
# 196  196   82.818   65.203           3
#
# [197 rows x 4 columns]
# Denny Hamlin
# Denny Hamlin.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          36
# 1      1   33.034  163.468          34
# 2      2   32.058  168.445          34
# 3      3   31.654  170.595          30
# 4      4   31.545  171.184          28
# ..   ...      ...      ...         ...
# 190  190   31.219  172.972           2
# 191  191   31.268  172.701           2
# 192  192   31.276  172.656           2
# 193  193   31.392  172.018           2
# 194  194   31.533  171.249           2
#
# [195 rows x 4 columns]
# Brad Keselowsk
# Brad Keselowsk.csv
#    Lap  LapTime LapSpeed  RunningPos
# 0    0      NaN     None          33
# 1    1   33.356  161.890          32
# 2    2   31.968  168.919          29
# 3    3   31.777  169.934          28
# 4    4   31.829  169.657          29
# 5    5   31.817  169.721          29
# 6    6   32.851  164.379          31
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File R:\miniconda\envs\peachy\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 37 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 16
#      14 # get driver name
#      15 driver_name = pd.DataFrame(data['laps'][driver_id])
# ---> 16 driver_name = driver_name['FullName'][driver_id]
#      17 driver_name = driver_name.lstrip('* ').rstrip(' #').rstrip('(i)')
#      19 print(driver_name)
#
# File R:\miniconda\envs\peachy\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File R:\miniconda\envs\peachy\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File R:\miniconda\envs\peachy\Lib\site-packages\pandas\core\indexes\range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 37
