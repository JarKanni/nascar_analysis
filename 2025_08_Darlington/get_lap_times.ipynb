# %%
import json
import pandas as pd
import numpy as np

# %%
driver_id = 0

# %%
# Get data into dataframe
with open('lap-times.json', 'r') as f:
    data = json.load(f)


df = pd.DataFrame(data['laps'][driver_id]['Laps'])

print(df)
# Out:
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           3
# 1      1   31.274  157.242           5
# 2      2   29.909  164.419           5
# 3      3   29.892  164.512           5
# 4      4   34.646  141.938           5
# ..   ...      ...      ...         ...
# 293  293  104.807   46.921           1
# 294  294   90.448   54.369           1
# 295  295   91.930   53.493           1
# 296  296   30.434  161.582           1
# 297  297   29.581  166.242           1
#
# [298 rows x 4 columns]

# %%
# get driver name
driver_name = pd.DataFrame(data['laps'][driver_id])
driver_name = driver_name['FullName'][driver_id]

driver_name = driver_name.lstrip('* ').rstrip(' #')

print(driver_name)
# Out:
# Denny Hamlin

# %%
# save as csv
driver_name = driver_name + '.csv'

print(driver_name)
df.to_csv(driver_name)
# Out:
# Denny Hamlin.csv

# %%
print(len(df['Lap']))
# Out:
# 298

# %%
for x in np.arange(43):

    driver_id = x
    
    # Get data into dataframe
    with open('lap-times.json', 'r') as f:
        data = json.load(f)
    
    
    df = pd.DataFrame(data['laps'][driver_id]['Laps'])
    
    print(df)
    
    # get driver name
    driver_name = pd.DataFrame(data['laps'][driver_id])
    driver_name = driver_name['FullName'][driver_id]
    driver_name = driver_name.lstrip('* ').rstrip(' #').rstrip('(i)')
    
    print(driver_name)
    
    
    # save as csv
    driver_name = driver_name + '.csv'
    
    print(driver_name)
    df.to_csv(driver_name)
# Out:
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           3
# 1      1   31.274  157.242           5
# 2      2   29.909  164.419           5
# 3      3   29.892  164.512           5
# 4      4   34.646  141.938           5
# ..   ...      ...      ...         ...
# 293  293  104.807   46.921           1
# 294  294   90.448   54.369           1
# 295  295   91.930   53.493           1
# 296  296   30.434  161.582           1
# 297  297   29.581  166.242           1
#
# [298 rows x 4 columns]
# Denny Hamlin
# Denny Hamlin.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           1
# 1      1   30.618  160.611           1
# 2      2   29.404  167.243           1
# 3      3   29.550  166.416           1
# 4      4   33.895  145.083           1
# ..   ...      ...      ...         ...
# 293  293  105.678   46.534           3
# 294  294   90.974   54.055           3
# 295  295   90.378   54.411           2
# 296  296   31.120  158.021           2
# 297  297   29.387  167.339           2
#
# [298 rows x 4 columns]
# William Byron
# William Byron.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          17
# 1      1   32.022  153.569          21
# 2      2   30.754  159.901          21
# 3      3   30.899  159.151          21
# 4      4   37.005  132.890          20
# ..   ...      ...      ...         ...
# 293  293   93.175   52.778           5
# 294  294   92.276   53.292           5
# 295  295   88.264   55.715           4
# 296  296   31.063  158.311           3
# 297  297   29.814  164.943           3
#
# [298 rows x 4 columns]
# Christopher Bell
# Christopher Bell.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           7
# 1      1   31.430  156.462           8
# 2      2   30.187  162.905           9
# 3      3   30.368  161.934           9
# 4      4   34.889  140.950           9
# ..   ...      ...      ...         ...
# 293  293   93.168   52.782           2
# 294  294   90.522   54.325           2
# 295  295   91.386   53.811           3
# 296  296   31.180  157.716           4
# 297  297   29.897  164.485           4
#
# [298 rows x 4 columns]
# Tyler Reddick
# Tyler Reddick.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           9
# 1      1   31.445  156.387          10
# 2      2   29.910  164.413           8
# 3      3   30.265  162.485           8
# 4      4   34.613  142.074           8
# ..   ...      ...      ...         ...
# 293  293   93.154   52.790           4
# 294  294   91.662   53.649           4
# 295  295   89.577   54.898           5
# 296  296   31.190  157.666           5
# 297  297   30.201  162.829           5
#
# [298 rows x 4 columns]
# Ryan Blaney
# Ryan Blaney.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          14
# 1      1   31.430  156.462          12
# 2      2   30.292  162.340          12
# 3      3   30.499  161.238          12
# 4      4   35.683  137.814          12
# ..   ...      ...      ...         ...
# 293  293   93.193   52.768           7
# 294  294   92.614   53.098           7
# 295  295   86.999   56.525           7
# 296  296   31.116  158.041           6
# 297  297   30.280  162.404           6
#
# [298 rows x 4 columns]
# Chris Buescher
# Chris Buescher.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          25
# 1      1   31.993  153.709          27
# 2      2   30.967  158.801          28
# 3      3   31.084  158.204          27
# 4      4   38.489  127.766          27
# ..   ...      ...      ...         ...
# 293  293  106.819   46.037           9
# 294  294   92.820   52.980           9
# 295  295   85.345   57.620           9
# 296  296   31.176  157.737           7
# 297  297   30.291  162.345           7
#
# [298 rows x 4 columns]
# Ross Chastain
# Ross Chastain.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          15
# 1      1   31.668  155.286          16
# 2      2   30.522  161.117          15
# 3      3   30.616  160.622          15
# 4      4   36.429  134.991          15
# ..   ...      ...      ...         ...
# 293  293  105.604   46.566           6
# 294  294   92.327   53.263           6
# 295  295   87.835   55.987           6
# 296  296   31.492  156.154           8
# 297  297   30.331  162.131           8
#
# [298 rows x 4 columns]
# Chase Elliott
# Chase Elliott.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          11
# 1      1   31.687  155.193          14
# 2      2   30.761  159.865          14
# 3      3   30.272  162.447          14
# 4      4   36.260  135.621          14
# ..   ...      ...      ...         ...
# 293  293  106.825   46.034          11
# 294  294   93.155   52.789          10
# 295  295   84.522   58.181          11
# 296  296   31.251  157.358           9
# 297  297   30.315  162.217           9
#
# [298 rows x 4 columns]
# Ty Gibbs
# Ty Gibbs.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           8
# 1      1   31.245  157.388           7
# 2      2   30.014  163.844           7
# 3      3   30.267  162.474           7
# 4      4   34.644  141.947           7
# ..   ...      ...      ...         ...
# 293  293   92.833   52.973           8
# 294  294   92.798   52.993           8
# 295  295   86.029   57.162           8
# 296  296   31.583  155.704          10
# 297  297   30.357  161.992          10
#
# [298 rows x 4 columns]
# Kyle Busch
# Kyle Busch.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           6
# 1      1   31.005  158.607           4
# 2      2   29.647  165.872           4
# 3      3   29.795  165.048           3
# 4      4   33.905  145.041           3
# ..   ...      ...      ...         ...
# 293  293  108.316   45.400          14
# 294  294   94.404   52.091          13
# 295  295   80.733   60.912          13
# 296  296   31.353  156.846          11
# 297  297   30.424  161.636          11
#
# [298 rows x 4 columns]
# Austin Cindric
# Austin Cindric.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          16
# 1      1   31.726  155.002          15
# 2      2   30.811  159.605          16
# 3      3   30.655  160.418          17
# 4      4   36.950  133.088          17
# ..   ...      ...      ...         ...
# 293  293  108.442   45.348          13
# 294  294   93.846   52.401          12
# 295  295   81.888   60.053          12
# 296  296   31.741  154.929          13
# 297  297   30.163  163.034          12
#
# [298 rows x 4 columns]
# Zane Smith
# Zane Smith.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          18
# 1      1   31.857  154.365          17
# 2      2   30.692  160.224          18
# 3      3   30.962  158.827          18
# 4      4   36.877  133.351          18
# ..   ...      ...      ...         ...
# 293  293  110.152   44.644          12
# 294  294   92.884   52.943          11
# 295  295   83.279   59.050          10
# 296  296   31.664  155.306          12
# 297  297   30.607  160.669          13
#
# [298 rows x 4 columns]
# Joey Logano
# Joey Logano.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          12
# 1      1   31.448  156.372          11
# 2      2   30.289  162.356          11
# 3      3   30.410  161.710          11
# 4      4   35.472  138.633          11
# ..   ...      ...      ...         ...
# 293  293  109.095   45.076          16
# 294  294   95.055   51.734          15
# 295  295   78.637   62.535          16
# 296  296   31.660  155.325          14
# 297  297   30.349  162.035          14
#
# [298 rows x 4 columns]
# Todd Gilliland
# Todd Gilliland.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          30
# 1      1   31.796  154.661          30
# 2      2   30.998  158.642          29
# 3      3   30.884  159.228          29
# 4      4   37.942  129.608          26
# ..   ...      ...      ...         ...
# 293  293  107.922   45.566          15
# 294  294   94.844   51.849          14
# 295  295   79.412   61.925          14
# 296  296   31.819  154.549          15
# 297  297   30.495  161.259          15
#
# [298 rows x 4 columns]
# Daniel Suarez
# Daniel Suarez.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          29
# 1      1   31.642  155.414          29
# 2      2   31.357  156.826          31
# 3      3   30.982  158.724          31
# 4      4   39.627  124.097          31
# ..   ...      ...      ...         ...
# 293  293   95.572   51.454          18
# 294  294   95.468   51.510          17
# 295  295   76.828   64.008          17
# 296  296   31.746  154.905          16
# 297  297   30.801  159.657          16
#
# [298 rows x 4 columns]
# Ty Dillon
# Ty Dillon.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          34
# 1      1   31.622  155.512          32
# 2      2   31.266  157.283          32
# 3      3   31.122  158.010          33
# 4      4   39.664  123.981          32
# ..   ...      ...      ...         ...
# 293  293  109.787   44.792          19
# 294  294   95.961   51.246          18
# 295  295   76.004   64.702          19
# 296  296   31.805  154.617          18
# 297  297   30.699  160.188          17
#
# [298 rows x 4 columns]
# Erik Jones
# Erik Jones.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          22
# 1      1   31.650  155.374          20
# 2      2   30.772  159.808          20
# 3      3   30.948  158.899          20
# 4      4   36.990  132.944          19
# ..   ...      ...      ...         ...
# 293  293  110.915   44.337          20
# 294  294   95.925   51.265          19
# 295  295   75.135   65.450          18
# 296  296   31.774  154.768          17
# 297  297   30.846  159.424          18
#
# [298 rows x 4 columns]
# AJ Allmendinger
# AJ Allmendinger.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          26
# 1      1   31.770  154.788          25
# 2      2   30.680  160.287          24
# 3      3   31.232  157.454          24
# 4      4   37.315  131.786          23
# ..   ...      ...      ...         ...
# 293  293   95.478   51.505          17
# 294  294   95.551   51.466          16
# 295  295   77.624   63.352          15
# 296  296   32.205  152.697          19
# 297  297   30.824  159.538          19
#
# [298 rows x 4 columns]
# Noah Gragson
# Noah Gragson.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          36
# 1      1   31.766  154.807          35
# 2      2   31.164  157.797          35
# 3      3   31.193  157.651          35
# 4      4   40.359  121.846          34
# ..   ...      ...      ...         ...
# 293  293   95.548   51.467          21
# 294  294   97.100   50.645          20
# 295  295   73.674   66.748          21
# 296  296   31.948  153.925          21
# 297  297   30.946  158.909          20
#
# [298 rows x 4 columns]
# Shane Van Gisbergen
# Shane Van Gisbergen.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           5
# 1      1   31.249  157.368           6
# 2      2   30.054  163.625           6
# 3      3   30.122  163.256           6
# 4      4   34.203  143.777           6
# ..   ...      ...      ...         ...
# 293  293   66.886   73.522          10
# 294  294  107.245   45.854          21
# 295  295   71.651   68.633          20
# 296  296   31.984  153.752          20
# 297  297   31.127  157.985          21
#
# [298 rows x 4 columns]
# Bubba Wallace
# Bubba Wallace.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          31
# 1      1   31.839  154.452          34
# 2      2   31.259  157.318          34
# 3      3   31.120  158.021          34
# 4      4   40.056  122.768          33
# ..   ...      ...      ...         ...
# 293  293   65.189   75.436          22
# 294  294   57.962   84.842          22
# 295  295   68.638   71.645          23
# 296  296   33.565  146.510          22
# 297  297   31.908  154.118          22
#
# [298 rows x 4 columns]
# Cole Custer
# Cole Custer.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          23
# 1      1   31.830  154.496          24
# 2      2   30.834  159.486          25
# 3      3   31.169  157.772          25
# 4      4   37.643  130.638          24
# ..   ...      ...      ...         ...
# 293  293   65.238   75.379          25
# 294  294   59.110   83.194          25
# 295  295   65.347   75.254          24
# 296  296   33.572  146.479          23
# 297  297   32.365  151.942          23
#
# [298 rows x 4 columns]
# Austin Dillon
# Austin Dillon.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          21
# 1      1   31.794  154.671          22
# 2      2   30.834  159.486          23
# 3      3   30.976  158.755          23
# 4      4   37.086  132.600          21
# ..   ...      ...      ...         ...
# 293  293   65.092   75.548          27
# 294  294   59.974   81.996          27
# 295  295   63.666   77.241          27
# 296  296   34.052  144.414          26
# 297  297   32.351  152.008          24
#
# [298 rows x 4 columns]
# Justin Haley
# Justin Haley.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          28
# 1      1   31.795  154.666          26
# 2      2   30.780  159.766          26
# 3      3   31.143  157.904          26
# 4      4   37.742  130.295          25
# ..   ...      ...      ...         ...
# 293  293   64.818   75.868          26
# 294  294   59.688   82.388          26
# 295  295   64.588   76.138          26
# 296  296   34.045  144.444          25
# 297  297   33.325  147.565          25
#
# [298 rows x 4 columns]
# Ricky Stenhouse Jr.
# Ricky Stenhouse Jr..csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           2
# 1      1   30.859  159.357           2
# 2      2   29.496  166.721           2
# 3      3   29.785  165.103           2
# 4      4   33.859  145.238           2
# ..   ...      ...      ...         ...
# 293  293   65.664   74.890          23
# 294  294   57.984   84.810          23
# 295  295   67.372   72.992          22
# 296  296   34.539  142.378          27
# 297  297   34.587  142.181          26
#
# [298 rows x 4 columns]
# Ryan Preece
# Ryan Preece.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          35
# 1      1   31.949  153.920          36
# 2      2   31.237  157.429          37
# 3      3   31.245  157.388          37
# 4      4   40.854  120.370          36
# ..   ...      ...      ...         ...
# 293  293   65.403   75.189          30
# 294  294   61.380   80.117          30
# 295  295   59.618   82.485          30
# 296  296   34.117  144.139          29
# 297  297   34.426  142.846          27
#
# [298 rows x 4 columns]
# Cody Ware
# Cody Ware.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None           4
# 1      1   30.871  159.295           3
# 2      2   29.717  165.481           3
# 3      3   30.057  163.609           4
# 4      4   34.340  143.203           4
# ..   ...      ...      ...         ...
# 293  293   65.782   74.756          29
# 294  294   60.712   80.999          29
# 295  295   60.989   80.631          29
# 296  296   34.312  143.320          30
# 297  297   35.009  140.467          28
#
# [298 rows x 4 columns]
# Chase Briscoe
# Chase Briscoe.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          10
# 1      1   31.558  155.827           9
# 2      2   30.193  162.872          10
# 3      3   30.396  161.784          10
# 4      4   35.073  140.210          10
# ..   ...      ...      ...         ...
# 293  293   65.008   75.646          24
# 294  294   58.858   83.550          24
# 295  295   66.410   74.049          25
# 296  296   34.110  144.169          24
# 297  297   50.523   97.334          29
#
# [298 rows x 4 columns]
# Michael McDowell
# Michael McDowell.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          27
# 1      1   31.799  154.646          28
# 2      2   30.833  159.491          27
# 3      3   31.216  157.535          28
# 4      4   38.659  127.205          28
# ..   ...      ...      ...         ...
# 293  293   64.580   76.147          28
# 294  294   61.380   80.117          28
# 295  295   61.660   79.753          28
# 296  296   34.312  143.320          28
# 297  297   65.230   75.389          30
#
# [298 rows x 4 columns]
# John Hunter Nemechek
# John Hunter Nemechek.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          37
# 1      1   31.795  154.666          37
# 2      2   31.054  158.356          36
# 3      3   31.212  157.555          36
# 4      4   40.482  121.476          35
# ..   ...      ...      ...         ...
# 292  292   65.313   75.293          31
# 293  293   56.906   86.416          31
# 294  294   69.744   70.509          31
# 295  295   33.082  148.649          31
# 296  296   31.944  153.944          31
#
# [297 rows x 4 columns]
# Austin Hill
# Austin Hill.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          13
# 1      1   31.516  156.035          13
# 2      2   30.368  161.934          13
# 3      3   30.369  161.928          13
# 4      4   35.954  136.775          13
# ..   ...      ...      ...         ...
# 292  292   65.509   75.068          32
# 293  293   61.201   80.352          32
# 294  294   60.096   81.829          32
# 295  295   34.286  143.429          32
# 296  296   34.458  142.713          32
#
# [297 rows x 4 columns]
# Carson Hocevar
# Carson Hocevar.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          20
# 1      1   31.886  154.224          19
# 2      2   30.449  161.503          17
# 3      3   30.601  160.701          16
# 4      4   36.510  134.692          16
# ..   ...      ...      ...         ...
# 291  291   65.613   74.949          33
# 292  292   56.514   87.016          33
# 293  293   70.708   69.548          33
# 294  294   33.711  145.875          33
# 295  295   32.833  149.776          33
#
# [296 rows x 4 columns]
# Brad Keselowsk
# Brad Keselowsk.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          32
# 1      1   31.776  154.758          31
# 2      2   31.016  158.550          30
# 3      3   30.937  158.955          30
# 4      4   38.662  127.195          29
# ..   ...      ...      ...         ...
# 291  291   64.810   75.877          34
# 292  292   60.604   81.143          34
# 293  293   62.608   78.546          34
# 294  294   34.059  144.385          34
# 295  295   33.538  146.628          34
#
# [296 rows x 4 columns]
# Riley Herbst
# Riley Herbst.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          33
# 1      1   31.458  156.323          33
# 2      2   31.261  157.308          33
# 3      3   30.874  159.280          32
# 4      4   39.069  125.870          30
# ..   ...      ...      ...         ...
# 276  276  112.367   43.764          35
# 277  277  108.861   45.173          35
# 278  278   65.700   74.849          35
# 279  279   29.426  167.118          35
# 280  280   38.495  127.746          35
#
# [281 rows x 4 columns]
# Alex Bowman
# Alex Bowman.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          24
# 1      1   31.692  155.168          23
# 2      2   30.675  160.313          22
# 3      3   31.057  158.341          22
# 4      4   37.591  130.819          22
# ..   ...      ...      ...         ...
# 191  191   93.397   52.653           6
# 192  192   93.987   52.322           6
# 193  193   86.221   57.035           7
# 194  194   31.244  157.393           5
# 195  195  360.881   13.627          36
#
# [196 rows x 4 columns]
# Josh Berry
# Josh Berry.csv
#      Lap  LapTime LapSpeed  RunningPos
# 0      0      NaN     None          19
# 1      1   31.735  154.958          18
# 2      2   30.796  159.683          19
# 3      3   30.716  160.099          19
# 4      4  301.987   16.284          38
# ..   ...      ...      ...         ...
# 118  118   57.433   85.623          37
# 119  119   43.794  112.289          37
# 120  120   30.982  158.724          37
# 121  121   30.986  158.704          37
# 122  122   91.986   53.460          37
#
# [123 rows x 4 columns]
# Kyle Larson
# Kyle Larson.csv
#     Lap  LapTime LapSpeed  RunningPos
# 0     0      NaN     None          38
# 1     1   32.136  153.025          38
# 2     2   31.239  157.419          38
# 3     3   31.427  156.477          38
# 4     4   40.992  119.965          37
# 5     5   91.287   53.870          37
# 6     6   80.632   60.988          25
# 7     7  119.047   41.308          37
# 8     8   55.218   89.058          37
# 9     9   32.675  150.500          37
# 10   10   31.539  155.921          37
# 11   11   31.787  154.705          37
# 12   12   31.768  154.797          37
# 13   13   31.865  154.326          37
# 14   14   31.862  154.341          37
# 15   15   31.791  154.685          37
# 16   16   32.123  153.087          37
# 17   17   31.946  153.935          37
# 18   18   31.977  153.786          37
# 19   19   32.200  152.720          37
# 20   20   32.241  152.526          37
# 21   21   32.230  152.578          37
# 22   22   32.299  152.252          37
# 23   23   32.825  149.813          36
# 24   24   43.312  113.539          36
# 25   25   70.308   69.944          36
# 26   26   71.180   69.087           6
# 27   27  108.205   45.447          19
# 28   28  115.286   42.656          36
# 29   29   57.785   85.102          36
# 30   30  154.579   31.813          37
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File R:\miniconda\envs\peachy\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 37 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 16
#      14 # get driver name
#      15 driver_name = pd.DataFrame(data['laps'][driver_id])
# ---> 16 driver_name = driver_name['FullName'][driver_id]
#      17 driver_name = driver_name.lstrip('* ').rstrip(' #').rstrip('(i)')
#      19 print(driver_name)
#
# File R:\miniconda\envs\peachy\Lib\site-packages\pandas\core\series.py:1121, in Series.__getitem__(self, key)
#    1118     return self._values[key]
#    1120 elif key_is_scalar:
# -> 1121     return self._get_value(key)
#    1123 # Convert generator to list before going through hashable part
#    1124 # (We will iterate through the generator there to check for slices)
#    1125 if is_iterator(key):
#
# File R:\miniconda\envs\peachy\Lib\site-packages\pandas\core\series.py:1237, in Series._get_value(self, label, takeable)
#    1234     return self._values[label]
#    1236 # Similar to Index.get_value, but we do not fall back to positional
# -> 1237 loc = self.index.get_loc(label)
#    1239 if is_integer(loc):
#    1240     return self._values[loc]
#
# File R:\miniconda\envs\peachy\Lib\site-packages\pandas\core\indexes\range.py:415, in RangeIndex.get_loc(self, key)
#     413         return self._range.index(new_key)
#     414     except ValueError as err:
# --> 415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
#     417     raise KeyError(key)
#
# KeyError: 37
